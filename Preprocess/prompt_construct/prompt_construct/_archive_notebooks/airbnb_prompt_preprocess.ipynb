# %%
import pandas as pd
from collections import Counter
import ast
import json
from tqdm import tqdm

# %%
# Load the CSV file (replace 'your_file.csv' with your actual filename)
file_path = '../../../Data/Raw_data/AirBnB_data.csv'
df = pd.read_csv(file_path, low_memory=False)
df.shape
# Out:
# (953953, 26)

# %%
category_columns = ['Property Type', 'Listing Type', 'Airbnb Response Time (Text)', 'Cancellation Policy',
                    'Check-in Time', 'Checkout Time']  # 'Amenities' 는 특수처리
binary_columns = ['Airbnb Superhost', 'Instantbook Enabled', 'Pets Allowed']
numerical_columns = ['Bedrooms', 'Bathrooms', 'Max Guests', 'Available Days', 'Blocked Days', 
                    'Response Rate', 'Number of Reviews', 'Minimum Stay', 'Number of Photos', 'Overall Rating']
listing_title = ['Listing Title']

print(len(category_columns), len(binary_columns), len(numerical_columns))
# Out:
# 6 3 10

# %%
# Amenities 전처리
def parse_amenities(amenities):
    try:
        if isinstance(amenities, str):
            if amenities.startswith("{"):  # JSON 형식
                amenities_dict = json.loads(amenities)  # JSON 파싱
                return [item.lower() for sublist in amenities_dict.values() for item in sublist]  # 소문자 변환
            elif amenities.startswith("["):  # 리스트 문자열 형식
                return [item.lower() for item in json.loads(amenities)]  # 소문자 변환
        return []
    except:
        return []

# 데이터 변환 적용
df["Amenities"] = df["Amenities"].apply(parse_amenities)

# %%
# Flatten & 빈도수 계산
all_amenities = [amenity for sublist in df["Amenities"] for amenity in sublist]
amenity_counts = Counter(all_amenities)
print(len(amenity_counts))

# 상위 50개 Amenities 출력
top_amenities = [amenity for amenity, count in amenity_counts.most_common(50)]
print("Top Amenities:", top_amenities)
# Out:
# 343
# Top Amenities: ['heating', 'wireless_internet', 'ac', 'essentials', 'kitchen', 'shampoo', 'washer', 'hair-dryer', 'hangers', 'fire_extinguisher', 'smoke_detector', 'laptop-friendly', 'tv', 'hot_water', 'iron', 'carbon_monoxide_detector', 'refrigerator', 'dishes_and_silverware', 'microwave', 'long_term_stays_allowed', 'first_aid_kit', 'stove', 'cable', 'bed_linens', 'cooking_basics', 'elevator', 'dryer', 'keypad', 'private-entrance', 'luggage_dropoff_allowed', 'free_parking', 'lock_on_bedroom_door', 'extra_pillows_and_blankets', 'breakfast', 'coffee_maker', 'paid_parking', 'room_darkening_shades', 'paid_parking_on_premises', 'host_checkin', 'pocket_wifi', 'ethernet_connection', 'window_guards', 'cleaning_before_checkout', 'patio_or_balcony', 'garden_or_backyard', 'street_parking', 'oven', 'internet', 'smartlock', 'single_level_home']

# %%
# 데이터 분리
dong_names = list(df['Dong_name'].unique())
dong_names.append('상계8동')

date_range = sorted(df['Reporting Month'].unique())
print(len(dong_names), len(date_range))

full_index = pd.MultiIndex.from_product([date_range, dong_names], names=['Reporting Month', 'Dong_name'])
df_keys = pd.DataFrame(index=full_index).reset_index()
df_keys
# Out:
# 424 67
#       Reporting Month Dong_name
# 0          2017-01-01       혜화동
# 1          2017-01-01       사근동
# 2          2017-01-01       연남동
# 3          2017-01-01       우이동
# 4          2017-01-01       사직동
# ...               ...       ...
# 28403      2022-07-01       번3동
# 28404      2022-07-01       무악동
# 28405      2022-07-01      쌍문2동
# 28406      2022-07-01      시흥4동
# 28407      2022-07-01      상계8동
#
# [28408 rows x 2 columns]

# %%
for col in numerical_columns:
    count = df[col].describe()
    print(count)
    print(count['mean'])
    print('========================================')
    break
# Out:
# count    953785.000000
# mean          1.263197
# std           1.350749
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max          50.000000
# Name: Bedrooms, dtype: float64
# 1.2631966323647363
# ========================================

# %%
df.loc[0:3, 'Listing Title']
# Out:
# 0    [Enkor Stay] Private room H Shared Flat SKKU
# 1    [Enkor Stay] Private room H Shared Flat SKKU
# 2               Cozy studio - 3mins Hanyang Univ.
# 3               Cozy studio - 3mins Hanyang Univ.
# Name: Listing Title, dtype: object

# %% [markdown]
# # Structured Summary Prompt 생성

# %%
SSP_df = df_keys.copy()
SSP_prompt_wo_listing = []
SSP_prompt_w_listing = []

for idx, row in tqdm(df_keys.iterrows(), total=len(df_keys), desc="Generating prompts"):
    month = row['Reporting Month']
    dong = row['Dong_name']
    
    ex_df = df.loc[(df['Reporting Month']==month) & (df['Dong_name']==dong), ]
    prompt = [f"[{month} | {dong}] AirBnB Feature Summary:"
              f"Total number of AirBnB: {len(ex_df)}"]
    
    if ex_df.empty:
        prompt.append('There is no AirBnB')
        SSP_prompt_wo_listing.append(prompt)
        SSP_prompt_w_listing.append(prompt)
        continue
    
    # 1. category_columns 처리
    category_prompt = [f"Category Column Attributes"]
    for col in category_columns:
        #print(col)
        category = [f"\nCategory: {col} Information: Total number with data: {len(ex_df[col])}"]
        vc = ex_df[col].value_counts()
        for val, count in vc.items():
            category.append(f"   {val}: {count}")
        category_prompt.extend(category)
    
    # <Amenities 처리> -> 리스트 내용 중 top_amenities에 있는 것만 추가
    amenities_series = ex_df['Amenities']
    total_amenities = []
    for val in amenities_series:
        try:
            items = ast.literal_eval(val) if isinstance(val, str) else val
            if isinstance(items, list):
                total_amenities.extend(items)  # 리스트를 펼쳐서 하나로 합쳐줌
        except:
            continue
    counts = Counter(total_amenities)
    
    # top_amenities 중에서만 필터링
    top_amenity_counts = {amenity: counts[amenity] for amenity in top_amenities if amenity in counts}
    
    category = [f"\nCategory: Amenities Information: Total number with data: {len(total_amenities)}"]
    for k, v in top_amenity_counts.items():
        category.append(f"   {k}: {v}")
    category_prompt.extend(category)
    category_prompt.append('---------------------------------------------------------------------------\n')
    
    # 2. binary_columns 처리
    binary_prompt = [f"Binary Column Attributes\n"]
    for col in binary_columns:
        #print(col)
        col_data = ex_df[col].dropna()
        total = len(col_data)
        
        # 값이 하나도 없으면 건너뛰기
        if total == 0:
            binary_prompt.append(f"{col} Information: No data available")
            continue
        
        binary = [f"{col} Information: Total number with data: {total}"]
        count = ex_df[col].sum()
        binary.append(f"number of {col}: {count}")
        binary_prompt.extend(binary)
    binary_prompt.append('---------------------------------------------------------------------------\n')
    
    # 3. numerical_columns 처리
    numerical_prompt = [f"Numerical Column Attributes"]
    for col in numerical_columns:
        #print(col)
        col_data = ex_df[col].dropna()
        total = len(col_data)
        
        # 값이 하나도 없으면 건너뛰기
        if total == 0:
            numerical_prompt.append(f"{col} Information: No data available")
            continue
        
        numerical = [f"{col} Information: Total number with data: {total}"]
        stats = col_data.describe()
        numerical.append(f"   Mean: {stats['mean']:.2f}")
        numerical.append(f"   Std Dev: {stats['std']:.2f}")
        numerical.append(f"   Median: {col_data.median():.2f}")
        numerical.append(f"   Min: {stats['min']:.2f}")
        numerical.append(f"   Max: {stats['max']:.2f}")
        numerical_prompt.extend(numerical)
    numerical_prompt.append('---------------------------------------------------------------------------\n')
        
    # 4. listing title 처리 (옵션)
    listing_series = ex_df['Listing Title']
    listing_list = []
    total = len(listing_series)
    
    listing_prompt = [f"AirBnB Listing Information: Total number with data: {total}"]
    
    for val in listing_series:
        listing_prompt.append(f"\'{val}\', ")
    
    listing_prompt.append('---------------------------------------------------------------------------\n')
    
    last_prompt = [f'Assume you are a data analyst that is familiar with AirBnB market. Give me the embedding of this {dong} at {month}']
    
    # 최종 프롬프트 합치기
    full_prompt_wo_listing = "\n".join(
        prompt + category_prompt + binary_prompt + numerical_prompt + last_prompt
    )
    full_prompt_w_listing = "\n".join(
        prompt + category_prompt + binary_prompt + numerical_prompt + listing_prompt + last_prompt
    )

    # 문자열로 저장
    SSP_prompt_wo_listing.append(full_prompt_wo_listing)
    SSP_prompt_w_listing.append(full_prompt_w_listing)
# Out:
# Generating prompts: 100%|██████████| 28408/28408 [41:52<00:00, 11.31it/s]

# %%
print(len(SSP_prompt_wo_listing))
print(len(SSP_prompt_w_listing))
SSP_prompt_wo_listing
# Out:
# 28408
# 28408
# ['[2017-01-01 | 혜화동] AirBnB Feature Summary:Total number of AirBnB: 84\nCategory Column Attributes\n\nCategory: Property Type Information: Total number with data: 84\n   House: 24\n   Bed and breakfast: 18\n   Rental unit: 10\n   Home: 9\n   Apartment: 5\n   Pension: 4\n   Bed & Breakfast: 4\n   Guesthouse: 2\n   Hostel: 2\n   Room in bed and breakfast: 1\n   Entire bed & breakfast: 1\n   Home/apt: 1\n   Pension (south korea): 1\n   Shared room in house: 1\n   Private room in house: 1\n\nCategory: Listing Type Information: Total number with data: 84\n   Private room: 42\n   Entire home/apt: 28\n   Shared room: 13\n   Hotel room: 1\n\nCategory: Airbnb Response Time (Text) Information: Total number with data: 84\n   within an hour: 46\n   within a few hours: 6\n   within a day: 3\n\nCategory: Cancellation Policy Information: Total number with data: 84\n   moderate: 23\n   strict_14_with_grace_period: 15\n   flexible: 13\n   Moderate: 9\n   strict: 8\n   Strict: 4\n   Free cancellation for 48 hours: 4\n   Flexible: 3\n   Strict - Free cancellation for 48 hours: 2\n   Flexible · Free cancellation for 48 hours: 1\n   Strict · Free cancellation for 48 hours: 1\n   Moderate - Free cancellation for 48 hours: 1\n\nCategory: Check-in Time Information: Total number with data: 84\n   After 3:00 PM: 25\n   After 3PM: 7\n   3PM - 12AM (midnight): 6\n   After 2PM: 5\n   After 2:00 PM: 4\n   Anytime after 3PM: 2\n   2:00 PM - 11:00 PM: 1\n   Anytime after 2AM: 1\n   Anytime after 2PM: 1\n   After 4PM: 1\n   4:00 PM - 9:00 PM: 1\n   4PM - 8PM: 1\n   3PM - 10PM: 1\n\nCategory: Checkout Time Information: Total number with data: 84\n   11:00 AM: 36\n   11AM: 20\n   12PM (noon): 7\n   10:00 AM: 3\n   12:00 PM: 2\n\nCategory: Amenities Information: Total number with data: 1325\n   heating: 80\n   wireless_internet: 81\n   ac: 72\n   essentials: 54\n   kitchen: 81\n   shampoo: 44\n   washer: 75\n   hair-dryer: 57\n   hangers: 52\n   fire_extinguisher: 54\n   smoke_detector: 50\n   laptop-friendly: 39\n   tv: 43\n   hot_water: 23\n   iron: 42\n   carbon_monoxide_detector: 9\n   refrigerator: 17\n   dishes_and_silverware: 16\n   microwave: 17\n   long_term_stays_allowed: 8\n   first_aid_kit: 32\n   stove: 14\n   cable: 45\n   bed_linens: 12\n   cooking_basics: 13\n   elevator: 12\n   dryer: 40\n   keypad: 5\n   private-entrance: 6\n   luggage_dropoff_allowed: 10\n   free_parking: 26\n   lock_on_bedroom_door: 19\n   extra_pillows_and_blankets: 8\n   breakfast: 49\n   coffee_maker: 8\n   paid_parking: 2\n   room_darkening_shades: 1\n   host_checkin: 8\n   cleaning_before_checkout: 1\n   patio_or_balcony: 4\n   garden_or_backyard: 8\n   street_parking: 6\n   oven: 2\n   internet: 13\n   single_level_home: 8\n---------------------------------------------------------------------------\n\nBinary Column Attributes\n\nAirbnb Superhost Information: Total number with data: 84\nnumber of Airbnb Superhost: 9\nInstantbook Enabled Information: Total number with data: 84\nnumber of Instantbook Enabled: 29\nPets Allowed Information: Total number with data: 84\nnumber of Pets Allowed: 3\n---------------------------------------------------------------------------\n\nNumerical Column Attributes\nBedrooms Information: Total number with data: 84\n   Mean: 1.23\n   Std Dev: 1.26\n   Median: 1.00\n   Min: 0.00\n   Max: 10.00\nBathrooms Information: Total number with data: 84\n   Mean: 1.42\n   Std Dev: 0.80\n   Median: 1.00\n   Min: 0.00\n   Max: 4.00\nMax Guests Information: Total number with data: 84\n   Mean: 3.32\n   Std Dev: 2.75\n   Median: 2.50\n   Min: 1.00\n   Max: 16.00\nAvailable Days Information: Total number with data: 84\n   Mean: 22.95\n   Std Dev: 8.52\n   Median: 26.00\n   Min: 0.00\n   Max: 31.00\nBlocked Days Information: Total number with data: 84\n   Mean: 3.25\n   Std Dev: 6.92\n   Median: 0.00\n   Min: 0.00\n   Max: 29.00\nResponse Rate Information: Total number with data: 81\n   Mean: 99.00\n   Std Dev: 3.43\n   Median: 100.00\n   Min: 80.00\n   Max: ...
#  '[2017-01-01 | 사근동] AirBnB Feature Summary:Total number of AirBnB: 25\nCategory Column Attributes\n\nCategory: Property Type Information: Total number with data: 25\n   Apartment: 10\n   Rental unit: 7\n   Shared room in apartment: 3\n   Private room in apartment: 1\n   Condo: 1\n   Other: 1\n   House: 1\n   Entire apartment: 1\n\nCategory: Listing Type Information: Total number with data: 25\n   Entire home/apt: 17\n   Shared room: 4\n   Private room: 4\n\nCategory: Airbnb Response Time (Text) Information: Total number with data: 25\n   within an hour: 9\n   within a day: 2\n   within a few hours: 2\n\nCategory: Cancellation Policy Information: Total number with data: 25\n   strict_14_with_grace_period: 9\n   strict: 7\n   moderate: 3\n   Strict policy  –  Free cancellation within 48 hours: 2\n   Free cancellation for 48 hours: 1\n   Strict · Free cancellation for 48 hours.: 1\n   flexible: 1\n   Flexible: 1\n\nCategory: Check-in Time Information: Total number with data: 25\n   After 3:00 PM: 10\n   Flexible: 4\n   After 3PM: 4\n   Anytime after 3PM: 4\n   Anytime after 2PM: 1\n   After 1:00 PM: 1\n   2PM - 2AM (next day): 1\n\nCategory: Checkout Time Information: Total number with data: 25\n   11:00 AM: 9\n   11AM: 6\n   12PM (noon): 4\n   1:00 PM: 1\n   10AM: 1\n   12:00 PM: 1\n   12AM (midnight): 1\n   10:00 AM: 1\n\nCategory: Amenities Information: Total number with data: 271\n   heating: 23\n   wireless_internet: 24\n   ac: 21\n   essentials: 18\n   kitchen: 24\n   shampoo: 19\n   washer: 24\n   hair-dryer: 7\n   hangers: 6\n   fire_extinguisher: 9\n   smoke_detector: 8\n   laptop-friendly: 6\n   tv: 9\n   hot_water: 3\n   iron: 2\n   carbon_monoxide_detector: 7\n   refrigerator: 1\n   dishes_and_silverware: 1\n   microwave: 1\n   long_term_stays_allowed: 3\n   first_aid_kit: 6\n   stove: 1\n   cable: 2\n   elevator: 8\n   dryer: 4\n   keypad: 3\n   luggage_dropoff_allowed: 2\n   free_parking: 6\n   lock_on_bedroom_door: 2\n   paid_parking: 1\n   internet: 3\n   smartlock: 1\n---------------------------------------------------------------------------\n\nBinary Column Attributes\n\nAirbnb Superhost Information: Total number with data: 25\nnumber of Airbnb Superhost: 1\nInstantbook Enabled Information: Total number with data: 25\nnumber of Instantbook Enabled: 2\nPets Allowed Information: Total number with data: 25\nnumber of Pets Allowed: 1\n---------------------------------------------------------------------------\n\nNumerical Column Attributes\nBedrooms Information: Total number with data: 25\n   Mean: 0.48\n   Std Dev: 0.51\n   Median: 0.00\n   Min: 0.00\n   Max: 1.00\nBathrooms Information: Total number with data: 25\n   Mean: 1.28\n   Std Dev: 0.58\n   Median: 1.00\n   Min: 1.00\n   Max: 2.50\nMax Guests Information: Total number with data: 25\n   Mean: 2.32\n   Std Dev: 1.73\n   Median: 2.00\n   Min: 1.00\n   Max: 8.00\nAvailable Days Information: Total number with data: 25\n   Mean: 16.56\n   Std Dev: 6.73\n   Median: 14.00\n   Min: 4.00\n   Max: 31.00\nBlocked Days Information: Total number with data: 25\n   Mean: 8.40\n   Std Dev: 6.77\n   Median: 9.00\n   Min: 0.00\n   Max: 18.00\nResponse Rate Information: Total number with data: 24\n   Mean: 79.17\n   Std Dev: 41.49\n   Median: 100.00\n   Min: 0.00\n   Max: 100.00\nNumber of Reviews Information: Total number with data: 25\n   Mean: 13.28\n   Std Dev: 19.47\n   Median: 5.00\n   Min: 0.00\n   Max: 82.00\nMinimum Stay Information: Total number with data: 25\n   Mean: 13.12\n   Std Dev: 40.43\n   Median: 2.00\n   Min: 1.00\n   Max: 200.00\nNumber of Photos Information: Total number with data: 25\n   Mean: 20.04\n   Std Dev: 16.44\n   Median: 14.00\n   Min: 1.00\n   Max: 53.00\nOverall Rating Information: Total number with data: 20\n   Mean: 91.30\n   Std Dev: 9.84\n   Median: 93.50\n   Min: 60.00\n   Max: 100.00\n---------------------------------------------------------------------------\n\nAssume you are a data analyst that is familiar with AirBnB market. Give  ...
#  '[2017-01-01 | 연남동] AirBnB Feature Summary:Total number of AirBnB: 399\nCategory Column Attributes\n\nCategory: Property Type Information: Total number with data: 399\n   House: 84\n   Apartment: 82\n   Bed and breakfast: 53\n   Home: 28\n   Guesthouse: 24\n   Hostel: 17\n   Bed & Breakfast: 17\n   Rental unit: 15\n   Room in bed and breakfast: 10\n   Loft: 10\n   Room in hostel: 10\n   Guest suite: 6\n   Condominium: 6\n   Shared room in bed and breakfast: 6\n   Other: 3\n   Entire apartment: 3\n   Residential home: 3\n   Dorm: 3\n   Entire house: 2\n   Private room in guesthouse: 2\n   Private room in condominium: 2\n   Condo: 2\n   Private room in apartment: 1\n   Shared room: 1\n   Hotel: 1\n   Room in serviced apartment: 1\n   Serviced apartment: 1\n   Room in hotel: 1\n   Private room in house: 1\n   Private room in bed and breakfast: 1\n   Place: 1\n   Floor: 1\n   Private room in bed & breakfast: 1\n\nCategory: Listing Type Information: Total number with data: 399\n   Private room: 203\n   Entire home/apt: 118\n   Shared room: 57\n   Hotel room: 21\n\nCategory: Airbnb Response Time (Text) Information: Total number with data: 399\n   within an hour: 175\n   within a day: 41\n   within a few hours: 41\n   a few days or more: 17\n\nCategory: Cancellation Policy Information: Total number with data: 399\n   strict_14_with_grace_period: 103\n   moderate: 74\n   strict: 32\n   flexible: 32\n   Strict - Free cancellation for 48 hours: 31\n   Flexible: 26\n   Moderate - Free cancellation for 48 hours: 24\n   Strict: 23\n   Moderate: 12\n   Strict · Free cancellation for 48 hours: 10\n   Free cancellation for 48 hours: 10\n   Flexible - Free cancellation for 48 hours: 7\n   Strict · Free cancellation for 48 hours.: 6\n   Moderate · Free cancellation for 48 hours: 3\n   firm: 3\n   Flexible policy –  Free cancellation within 48 hours: 1\n   Moderate · Free cancellation for 48 hours.: 1\n   Strict policy  –  Free cancellation within 48 hours: 1\n\nCategory: Check-in Time Information: Total number with data: 399\n   After 2:00 PM: 58\n   After 3:00 PM: 47\n   After 3PM: 40\n   Anytime after 3PM: 28\n   After 2PM: 24\n   2:00 PM - 8:00 PM: 17\n   Anytime after 2PM: 16\n   2PM - 11PM: 13\n   3:00 PM - 7:00 PM: 10\n   3PM - 11PM: 8\n   Flexible: 8\n   3:00 PM - 12:00 AM: 8\n   3:00 PM - 10:00 PM: 7\n   After 4:00 PM: 6\n   3:00 PM - 11:00 PM: 6\n   3PM - 2AM (next day): 6\n   2:00 PM - 12:00 AM: 6\n   1PM - 12AM (midnight): 4\n   1:00 PM - 11:00 PM: 3\n   3PM - 9PM: 3\n   1PM - 11PM: 3\n   3:00 PM - 2:00 AM (next day): 3\n   2PM - 8PM: 3\n   3:00 PM - 6:00 PM: 3\n   2:00 PM - 1:00 AM (next day): 2\n   2PM - 10PM: 2\n   After 12PM (noon): 2\n   2:00 PM - 11:00 PM: 2\n   3PM - 6PM: 2\n   6PM - 2AM (next day): 2\n   After 4PM: 2\n   3PM - 10PM: 2\n   3PM - 12AM (midnight): 2\n   3:00 PM - 9:00 PM: 2\n   2PM - 9PM: 1\n   After 1PM: 1\n   Anytime after 1PM: 1\n   After 2:00 AM: 1\n   11AM - 11PM: 1\n   2PM - 12AM (midnight): 1\n   11:00 AM - 9:00 PM: 1\n   After 1:00 PM: 1\n   2:00 PM - 9:00 PM: 1\n   8PM - 1AM (next day): 1\n   Anytime after 12PM (noon): 1\n   6:00 PM - 2:00 AM (next day): 1\n   2:00 PM - 2:00 AM (next day): 1\n   11AM - 10PM: 1\n   1PM - 2AM (next day): 1\n   Anytime after 4PM: 1\n   After 6PM: 1\n\nCategory: Checkout Time Information: Total number with data: 399\n   11:00 AM: 160\n   11AM: 124\n   12PM (noon): 39\n   12:00 PM: 24\n   12AM (midnight): 3\n   10AM: 2\n   3:00 PM: 1\n   5PM: 1\n   1:00 PM: 1\n   2:00 PM: 1\n   1PM: 1\n\nCategory: Amenities Information: Total number with data: 7020\n   heating: 381\n   wireless_internet: 387\n   ac: 355\n   essentials: 320\n   kitchen: 340\n   shampoo: 289\n   washer: 357\n   hair-dryer: 289\n   hangers: 267\n   fire_extinguisher: 289\n   smoke_detector: 282\n   laptop-friendly: 222\n   tv: 262\n   hot_water: 176\n   iron: 197\n   carbon_monoxide_detector: 122\n   refrigerator: 117\n   dishes_and_silverware: 93\n   microwave: 107\n   long_term_stays_allowed: 122\n   first_a ...
#  '[2017-01-01 | 우이동] AirBnB Feature Summary:Total number of AirBnB: 6\nCategory Column Attributes\n\nCategory: Property Type Information: Total number with data: 6\n   Home: 2\n   Bed and breakfast: 1\n   Nature lodge: 1\n   Apartment: 1\n   Guesthouse: 1\n\nCategory: Listing Type Information: Total number with data: 6\n   Entire home/apt: 3\n   Private room: 3\n\nCategory: Airbnb Response Time (Text) Information: Total number with data: 6\n   within an hour: 2\n\nCategory: Cancellation Policy Information: Total number with data: 6\n   strict_14_with_grace_period: 2\n   Flexible: 2\n   flexible: 1\n   strict: 1\n\nCategory: Check-in Time Information: Total number with data: 6\n   After 3:00 PM: 1\n   3PM - 8PM: 1\n   1PM - 10PM: 1\n   1:00 PM - 10:00 PM: 1\n\nCategory: Checkout Time Information: Total number with data: 6\n   11:00 AM: 2\n   11AM: 2\n\nCategory: Amenities Information: Total number with data: 135\n   heating: 6\n   wireless_internet: 6\n   ac: 4\n   essentials: 5\n   kitchen: 6\n   shampoo: 4\n   washer: 6\n   hair-dryer: 4\n   hangers: 4\n   fire_extinguisher: 4\n   smoke_detector: 5\n   laptop-friendly: 4\n   tv: 6\n   hot_water: 3\n   iron: 4\n   carbon_monoxide_detector: 4\n   refrigerator: 2\n   dishes_and_silverware: 2\n   microwave: 2\n   long_term_stays_allowed: 3\n   first_aid_kit: 5\n   stove: 2\n   cable: 5\n   bed_linens: 2\n   cooking_basics: 2\n   elevator: 1\n   dryer: 3\n   keypad: 1\n   private-entrance: 2\n   luggage_dropoff_allowed: 3\n   free_parking: 4\n   lock_on_bedroom_door: 2\n   extra_pillows_and_blankets: 2\n   breakfast: 3\n   coffee_maker: 1\n   host_checkin: 1\n   pocket_wifi: 1\n   cleaning_before_checkout: 1\n   patio_or_balcony: 2\n   garden_or_backyard: 2\n   street_parking: 2\n   oven: 1\n   internet: 1\n   smartlock: 1\n---------------------------------------------------------------------------\n\nBinary Column Attributes\n\nAirbnb Superhost Information: Total number with data: 6\nnumber of Airbnb Superhost: 0\nInstantbook Enabled Information: Total number with data: 6\nnumber of Instantbook Enabled: 4\nPets Allowed Information: Total number with data: 6\nnumber of Pets Allowed: 0\n---------------------------------------------------------------------------\n\nNumerical Column Attributes\nBedrooms Information: Total number with data: 6\n   Mean: 1.67\n   Std Dev: 0.82\n   Median: 1.50\n   Min: 1.00\n   Max: 3.00\nBathrooms Information: Total number with data: 6\n   Mean: 0.75\n   Std Dev: 0.42\n   Median: 1.00\n   Min: 0.00\n   Max: 1.00\nMax Guests Information: Total number with data: 6\n   Mean: 3.50\n   Std Dev: 2.07\n   Median: 4.00\n   Min: 1.00\n   Max: 6.00\nAvailable Days Information: Total number with data: 6\n   Mean: 27.17\n   Std Dev: 4.02\n   Median: 28.00\n   Min: 21.00\n   Max: 31.00\nBlocked Days Information: Total number with data: 6\n   Mean: 0.50\n   Std Dev: 1.22\n   Median: 0.00\n   Min: 0.00\n   Max: 3.00\nResponse Rate Information: Total number with data: 6\n   Mean: 100.00\n   Std Dev: 0.00\n   Median: 100.00\n   Min: 100.00\n   Max: 100.00\nNumber of Reviews Information: Total number with data: 6\n   Mean: 20.33\n   Std Dev: 35.68\n   Median: 2.50\n   Min: 0.00\n   Max: 90.00\nMinimum Stay Information: Total number with data: 6\n   Mean: 5.50\n   Std Dev: 5.05\n   Median: 3.50\n   Min: 1.00\n   Max: 15.00\nNumber of Photos Information: Total number with data: 6\n   Mean: 25.67\n   Std Dev: 20.08\n   Median: 21.50\n   Min: 3.00\n   Max: 55.00\nOverall Rating Information: Total number with data: 4\n   Mean: 98.50\n   Std Dev: 1.91\n   Median: 99.00\n   Min: 96.00\n   Max: 100.00\n---------------------------------------------------------------------------\n\nAssume you are a data analyst that is familiar with AirBnB market. Give me the embedding of this 우이동 at 2017-01-01',
#  '[2017-01-01 | 사직동] AirBnB Feature Summary:Total number of AirBnB: 169\nCategory Column Attributes\n\nCategory: Property Type Information: Total number with data: 169\n   Apartment: 56\n   House: 34\n   Bed and breakfast: 20\n   Guesthouse: 13\n   Home: 11\n   Rental unit: 8\n   Bed & Breakfast: 7\n   Condominium: 5\n   Entire apartment: 4\n   Guest suite: 3\n   Room in boutique hotel: 2\n   Loft: 2\n   Condo: 1\n   Villa: 1\n   Entire house: 1\n   Private room in bed & breakfast: 1\n\nCategory: Listing Type Information: Total number with data: 169\n   Entire home/apt: 88\n   Private room: 70\n   Shared room: 11\n\nCategory: Airbnb Response Time (Text) Information: Total number with data: 169\n   within an hour: 68\n   within a few hours: 12\n   within a day: 6\n   a few days or more: 2\n\nCategory: Cancellation Policy Information: Total number with data: 169\n   Strict: 40\n   strict_14_with_grace_period: 22\n   flexible: 20\n   strict: 19\n   moderate: 16\n   Free cancellation for 48 hours: 15\n   Strict - Free cancellation for 48 hours: 9\n   Flexible: 6\n   Moderate - Free cancellation for 48 hours: 5\n   Flexible · Free cancellation for 48 hours.: 3\n   Flexible - Free cancellation for 48 hours: 3\n   firm: 3\n   Moderate: 2\n   Flexible · Free cancellation for 48 hours: 2\n   Strict · Free cancellation for 48 hours: 2\n   Flexible policy –  Free cancellation within 48 hours: 2\n\nCategory: Check-in Time Information: Total number with data: 169\n   Anytime after 3PM: 33\n   3:00 PM - 10:00 PM: 13\n   After 3:00 PM: 11\n   After 3PM: 10\n   Anytime after 2PM: 10\n   3PM - 10PM: 7\n   Flexible: 7\n   3PM - 2AM (next day): 6\n   3:00 PM - 11:00 PM: 6\n   After 2PM: 6\n   Anytime after 4PM: 3\n   2PM - 10PM: 3\n   2:00 PM - 11:00 PM: 3\n   After 1PM: 2\n   5:00 PM - 9:00 PM: 2\n   3:00 PM - 1:00 AM (next day): 2\n   After 4:00 PM: 2\n   Anytime after 6PM: 1\n   3PM - 11PM: 1\n   4PM - 2AM (next day): 1\n   3:00 PM - 5:00 PM: 1\n   3PM - 6PM: 1\n   4:00 PM - 11:00 PM: 1\n   2:00 PM - 10:00 PM: 1\n   Anytime after 1PM: 1\n   2PM - 11PM: 1\n   4PM - 9PM: 1\n   After 4PM: 1\n   2PM - 2AM (next day): 1\n   After 2:00 PM: 1\n   4:00 PM - 10:00 PM: 1\n   4:00 PM - 2:00 AM (next day): 1\n   %{start_time} - %{end_time}: 1\n   11:00 AM - 11:00 PM: 1\n   3PM - 1AM (next day): 1\n\nCategory: Checkout Time Information: Total number with data: 169\n   11AM: 63\n   11:00 AM: 38\n   12PM (noon): 18\n   12:00 PM: 5\n   10AM: 3\n   10:00 AM: 2\n   1PM: 1\n   10:00 PM: 1\n   12AM (midnight): 1\n\nCategory: Amenities Information: Total number with data: 2794\n   heating: 165\n   wireless_internet: 165\n   ac: 150\n   essentials: 101\n   kitchen: 152\n   shampoo: 102\n   washer: 163\n   hair-dryer: 89\n   hangers: 86\n   fire_extinguisher: 94\n   smoke_detector: 77\n   laptop-friendly: 79\n   tv: 117\n   hot_water: 46\n   iron: 68\n   carbon_monoxide_detector: 53\n   refrigerator: 42\n   dishes_and_silverware: 39\n   microwave: 40\n   long_term_stays_allowed: 31\n   first_aid_kit: 59\n   stove: 37\n   cable: 78\n   bed_linens: 24\n   cooking_basics: 34\n   elevator: 59\n   dryer: 96\n   keypad: 17\n   private-entrance: 18\n   luggage_dropoff_allowed: 27\n   free_parking: 26\n   lock_on_bedroom_door: 23\n   extra_pillows_and_blankets: 13\n   breakfast: 48\n   coffee_maker: 28\n   paid_parking: 20\n   room_darkening_shades: 9\n   paid_parking_on_premises: 11\n   host_checkin: 15\n   pocket_wifi: 7\n   ethernet_connection: 3\n   window_guards: 5\n   cleaning_before_checkout: 1\n   patio_or_balcony: 5\n   garden_or_backyard: 14\n   street_parking: 4\n   oven: 4\n   internet: 39\n   smartlock: 4\n   single_level_home: 10\n---------------------------------------------------------------------------\n\nBinary Column Attributes\n\nAirbnb Superhost Information: Total number with data: 169\nnumber of Airbnb Superhost: 21\nInstantbook Enabled Information: Total number with data: 169\nnumber of Instantbook Enabled: 59\nPets Allowed Information: Total number  ...
#  '[2017-01-01 | 신길1동] AirBnB Feature Summary:Total number of AirBnB: 9\nCategory Column Attributes\n\nCategory: Property Type Information: Total number with data: 9\n   Home: 3\n   Apartment: 2\n   House: 2\n   Entire house: 1\n   Rental unit: 1\n\nCategory: Listing Type Information: Total number with data: 9\n   Private room: 5\n   Entire home/apt: 3\n   Shared room: 1\n\nCategory: Airbnb Response Time (Text) Information: Total number with data: 9\n   within a day: 3\n   within a few hours: 1\n   within an hour: 1\n\nCategory: Cancellation Policy Information: Total number with data: 9\n   moderate: 3\n   Flexible: 2\n   strict: 1\n   Strict - Free cancellation for 48 hours: 1\n   strict_14_with_grace_period: 1\n   flexible: 1\n\nCategory: Check-in Time Information: Total number with data: 9\n   Anytime after 3PM: 2\n   Anytime after 2PM: 1\n   Flexible: 1\n   After 3:00 PM: 1\n   3:00 PM - 10:00 PM: 1\n   After 2PM: 1\n\nCategory: Checkout Time Information: Total number with data: 9\n   11:00 AM: 4\n   11AM: 2\n   12AM (midnight): 1\n\nCategory: Amenities Information: Total number with data: 165\n   heating: 9\n   wireless_internet: 9\n   ac: 8\n   essentials: 6\n   kitchen: 7\n   shampoo: 7\n   washer: 9\n   hair-dryer: 6\n   hangers: 5\n   fire_extinguisher: 7\n   smoke_detector: 6\n   laptop-friendly: 5\n   tv: 7\n   hot_water: 5\n   iron: 3\n   carbon_monoxide_detector: 1\n   refrigerator: 3\n   dishes_and_silverware: 1\n   long_term_stays_allowed: 4\n   first_aid_kit: 5\n   stove: 1\n   cable: 4\n   bed_linens: 3\n   cooking_basics: 1\n   elevator: 3\n   dryer: 3\n   private-entrance: 1\n   luggage_dropoff_allowed: 3\n   free_parking: 3\n   lock_on_bedroom_door: 2\n   breakfast: 2\n   host_checkin: 1\n   cleaning_before_checkout: 3\n   patio_or_balcony: 2\n   garden_or_backyard: 3\n   street_parking: 2\n   internet: 2\n   single_level_home: 1\n---------------------------------------------------------------------------\n\nBinary Column Attributes\n\nAirbnb Superhost Information: Total number with data: 9\nnumber of Airbnb Superhost: 0\nInstantbook Enabled Information: Total number with data: 9\nnumber of Instantbook Enabled: 1\nPets Allowed Information: Total number with data: 9\nnumber of Pets Allowed: 0\n---------------------------------------------------------------------------\n\nNumerical Column Attributes\nBedrooms Information: Total number with data: 9\n   Mean: 1.44\n   Std Dev: 0.88\n   Median: 1.00\n   Min: 1.00\n   Max: 3.00\nBathrooms Information: Total number with data: 9\n   Mean: 1.11\n   Std Dev: 0.33\n   Median: 1.00\n   Min: 1.00\n   Max: 2.00\nMax Guests Information: Total number with data: 9\n   Mean: 3.00\n   Std Dev: 2.24\n   Median: 2.00\n   Min: 1.00\n   Max: 7.00\nAvailable Days Information: Total number with data: 9\n   Mean: 25.67\n   Std Dev: 7.63\n   Median: 28.00\n   Min: 7.00\n   Max: 31.00\nBlocked Days Information: Total number with data: 9\n   Mean: 3.33\n   Std Dev: 7.83\n   Median: 0.00\n   Min: 0.00\n   Max: 24.00\nResponse Rate Information: Total number with data: 9\n   Mean: 82.89\n   Std Dev: 24.70\n   Median: 100.00\n   Min: 50.00\n   Max: 100.00\nNumber of Reviews Information: Total number with data: 9\n   Mean: 20.11\n   Std Dev: 43.69\n   Median: 6.00\n   Min: 1.00\n   Max: 136.00\nMinimum Stay Information: Total number with data: 9\n   Mean: 6.56\n   Std Dev: 10.11\n   Median: 2.00\n   Min: 1.00\n   Max: 28.00\nNumber of Photos Information: Total number with data: 9\n   Mean: 16.89\n   Std Dev: 7.13\n   Median: 19.00\n   Min: 5.00\n   Max: 27.00\nOverall Rating Information: Total number with data: 9\n   Mean: 93.44\n   Std Dev: 8.49\n   Median: 94.00\n   Min: 73.00\n   Max: 100.00\n---------------------------------------------------------------------------\n\nAssume you are a data analyst that is familiar with AirBnB market. Give me the embedding of this 신길1동 at 2017-01-01',
#  '[2017-01-01 | 서교동] AirBnB Feature Summary:Total number of AirBnB: 1545\nCategory Column Attributes\n\nCategory: Property Type Information: Total number with data: 1545\n   Apartment: 613\n   House: 270\n   Bed & Breakfast: 98\n   Bed and breakfast: 97\n   Guesthouse: 65\n   Rental unit: 53\n   Condominium: 51\n   Entire apartment: 34\n   Home: 32\n   Serviced apartment: 27\n   Loft: 26\n   Hostel: 26\n   Room in hostel: 21\n   Private room in house: 14\n   Condo: 14\n   Entire house: 13\n   Other: 10\n   Private room in bed & breakfast: 10\n   Townhouse: 8\n   Room in bed and breakfast: 7\n   Private room in guesthouse: 6\n   Private room in apartment: 6\n   Dorm: 6\n   Residential home: 5\n   Room in hotel: 5\n   Shared room in guesthouse: 5\n   Bed &amp; Breakfast: 4\n   Room in aparthotel: 4\n   Shared room in bed & breakfast: 4\n   Room in serviced apartment: 2\n   Shared room in hostel: 2\n   Guest suite: 2\n   Private room in townhouse: 1\n   Place: 1\n   Shared room in house: 1\n   Private room in guest suite: 1\n   Entire hostel: 1\n\nCategory: Listing Type Information: Total number with data: 1545\n   Entire home/apt: 852\n   Private room: 484\n   Shared room: 179\n   Hotel room: 30\n\nCategory: Airbnb Response Time (Text) Information: Total number with data: 1545\n   within an hour: 512\n   within a few hours: 105\n   within a day: 68\n   a few days or more: 45\n\nCategory: Cancellation Policy Information: Total number with data: 1545\n   strict_14_with_grace_period: 307\n   Strict: 303\n   strict: 261\n   Strict - Free cancellation for 48 hours: 131\n   moderate: 117\n   flexible: 95\n   Free cancellation for 48 hours: 62\n   Moderate: 57\n   Flexible: 55\n   Moderate - Free cancellation for 48 hours: 52\n   Strict · Free cancellation for 48 hours: 32\n   Flexible - Free cancellation for 48 hours: 21\n   Strict · Free cancellation for 48 hours.: 12\n   Strict policy  –  Free cancellation within 48 hours: 11\n   Moderate · Free cancellation for 48 hours.: 8\n   Moderate · Free cancellation for 48 hours: 7\n   Flexible · Free cancellation for 48 hours: 4\n   firm: 3\n   Moderate policy –  Free cancellation within 48 hours: 2\n   Flexible · Free cancellation for 48 hours.: 2\n   better_strict: 1\n   Flexible policy –  Free cancellation within 48 hours: 1\n   super_strict_30: 1\n\nCategory: Check-in Time Information: Total number with data: 1545\n   Anytime after 3PM: 289\n   After 3:00 PM: 174\n   After 3PM: 166\n   Anytime after 2PM: 105\n   3PM - 2AM (next day): 78\n   Flexible: 67\n   After 2PM: 59\n   After 2:00 PM: 50\n   3PM - 10PM: 35\n   Anytime after 4PM: 26\n   3:00 PM - 12:00 AM: 23\n   3:00 PM - 2:00 AM (next day): 23\n   Anytime after 1PM: 21\n   3:00 PM - 11:00 PM: 21\n   2:00 PM - 2:00 AM (next day): 21\n   After 4PM: 19\n   3:00 PM - 10:00 PM: 17\n   3PM - 12AM (midnight): 16\n   3PM - 11PM: 16\n   2:00 PM - 10:00 PM: 14\n   2PM - 12AM (midnight): 14\n   2PM - 2AM (next day): 14\n   2PM - 11PM: 13\n   After 4:00 PM: 13\n   1:00 PM - 12:00 AM: 8\n   1PM - 11PM: 8\n   4PM - 2AM (next day): 7\n   After 12:00 PM: 7\n   2PM - 9PM: 5\n   3PM - 8PM: 4\n   After 5:00 PM: 4\n   2PM - 1AM (next day): 4\n   4PM - 11PM: 4\n   After 8AM: 3\n   4PM - 12AM (midnight): 3\n   Anytime after 2AM: 3\n   4:00 PM - 12:00 AM: 3\n   Anytime after 6PM: 3\n   2:00 PM - 12:00 AM: 3\n   4:00 PM - 11:00 PM: 2\n   After 12PM (noon): 2\n   3PM - 9PM: 2\n   3PM - 5PM: 2\n   3:00 PM - 5:00 PM: 2\n   2:00 PM - 11:00 PM: 2\n   Anytime after 12PM (noon): 2\n   1PM - 12AM (midnight): 2\n   After 1:00 PM: 2\n   Anytime after 11AM: 2\n   After %{time}: 1\n   After 11:00 AM: 1\n   12:00 AM - 2:00 AM (next day): 1\n   9:00 AM - 12:00 AM: 1\n   After 9:00 AM: 1\n   3PM - 4PM: 1\n   2:00 PM - 9:00 PM: 1\n   1PM - 10PM: 1\n   3:00 PM - 7:00 PM: 1\n   4PM - 10PM: 1\n   6PM - 10PM: 1\n   6PM - 2AM (next day): 1\n   2PM - 8PM: 1\n   Anytime after 7PM: 1\n   5:00 PM - 12:00 AM: 1\n   3:00 PM - 1:00 AM (next day): 1\n   10AM - 12AM (midnight): 1\n   ...
#  '[2017-01-01 | 신길6동] AirBnB Feature Summary:Total number of AirBnB: 1\nCategory Column Attributes\n\nCategory: Property Type Information: Total number with data: 1\n   Apartment: 1\n\nCategory: Listing Type Information: Total number with data: 1\n   Private room: 1\n\nCategory: Airbnb Response Time (Text) Information: Total number with data: 1\n   within an hour: 1\n\nCategory: Cancellation Policy Information: Total number with data: 1\n   Flexible · Free cancellation for 48 hours.: 1\n\nCategory: Check-in Time Information: Total number with data: 1\n\nCategory: Checkout Time Information: Total number with data: 1\n\nCategory: Amenities Information: Total number with data: 9\n   heating: 1\n   wireless_internet: 1\n   ac: 1\n   essentials: 1\n   kitchen: 1\n   shampoo: 1\n   cable: 1\n   elevator: 1\n   host_checkin: 1\n---------------------------------------------------------------------------\n\nBinary Column Attributes\n\nAirbnb Superhost Information: Total number with data: 1\nnumber of Airbnb Superhost: 0\nInstantbook Enabled Information: Total number with data: 1\nnumber of Instantbook Enabled: 0\nPets Allowed Information: Total number with data: 1\nnumber of Pets Allowed: False\n---------------------------------------------------------------------------\n\nNumerical Column Attributes\nBedrooms Information: Total number with data: 1\n   Mean: 1.00\n   Std Dev: nan\n   Median: 1.00\n   Min: 1.00\n   Max: 1.00\nBathrooms Information: Total number with data: 1\n   Mean: 2.00\n   Std Dev: nan\n   Median: 2.00\n   Min: 2.00\n   Max: 2.00\nMax Guests Information: Total number with data: 1\n   Mean: 2.00\n   Std Dev: nan\n   Median: 2.00\n   Min: 2.00\n   Max: 2.00\nAvailable Days Information: Total number with data: 1\n   Mean: 31.00\n   Std Dev: nan\n   Median: 31.00\n   Min: 31.00\n   Max: 31.00\nBlocked Days Information: Total number with data: 1\n   Mean: 0.00\n   Std Dev: nan\n   Median: 0.00\n   Min: 0.00\n   Max: 0.00\nResponse Rate Information: Total number with data: 1\n   Mean: 100.00\n   Std Dev: nan\n   Median: 100.00\n   Min: 100.00\n   Max: 100.00\nNumber of Reviews Information: Total number with data: 1\n   Mean: 0.00\n   Std Dev: nan\n   Median: 0.00\n   Min: 0.00\n   Max: 0.00\nMinimum Stay Information: Total number with data: 1\n   Mean: 1.00\n   Std Dev: nan\n   Median: 1.00\n   Min: 1.00\n   Max: 1.00\nNumber of Photos Information: Total number with data: 1\n   Mean: 2.00\n   Std Dev: nan\n   Median: 2.00\n   Min: 2.00\n   Max: 2.00\nOverall Rating Information: No data available\n---------------------------------------------------------------------------\n\nAssume you are a data analyst that is familiar with AirBnB market. Give me the embedding of this 신길6동 at 2017-01-01',
#  '[2017-01-01 | 신길7동] AirBnB Feature Summary:Total number of AirBnB: 2\nCategory Column Attributes\n\nCategory: Property Type Information: Total number with data: 2\n   Home: 1\n   Apartment: 1\n\nCategory: Listing Type Information: Total number with data: 2\n   Entire home/apt: 1\n   Private room: 1\n\nCategory: Airbnb Response Time (Text) Information: Total number with data: 2\n   within an hour: 1\n\nCategory: Cancellation Policy Information: Total number with data: 2\n   moderate: 1\n   strict_14_with_grace_period: 1\n\nCategory: Check-in Time Information: Total number with data: 2\n   After 3:00 PM: 1\n\nCategory: Checkout Time Information: Total number with data: 2\n   11:00 AM: 1\n\nCategory: Amenities Information: Total number with data: 35\n   heating: 2\n   wireless_internet: 2\n   ac: 1\n   essentials: 2\n   kitchen: 1\n   shampoo: 1\n   washer: 2\n   hair-dryer: 2\n   hangers: 2\n   fire_extinguisher: 2\n   smoke_detector: 2\n   laptop-friendly: 2\n   tv: 1\n   hot_water: 1\n   iron: 2\n   carbon_monoxide_detector: 1\n   cable: 1\n   elevator: 1\n   free_parking: 2\n   lock_on_bedroom_door: 1\n   breakfast: 1\n   host_checkin: 1\n   smartlock: 1\n---------------------------------------------------------------------------\n\nBinary Column Attributes\n\nAirbnb Superhost Information: Total number with data: 2\nnumber of Airbnb Superhost: 0\nInstantbook Enabled Information: Total number with data: 2\nnumber of Instantbook Enabled: 1\nPets Allowed Information: Total number with data: 2\nnumber of Pets Allowed: 0\n---------------------------------------------------------------------------\n\nNumerical Column Attributes\nBedrooms Information: Total number with data: 2\n   Mean: 1.50\n   Std Dev: 0.71\n   Median: 1.50\n   Min: 1.00\n   Max: 2.00\nBathrooms Information: Total number with data: 2\n   Mean: 1.00\n   Std Dev: 0.00\n   Median: 1.00\n   Min: 1.00\n   Max: 1.00\nMax Guests Information: Total number with data: 2\n   Mean: 2.50\n   Std Dev: 2.12\n   Median: 2.50\n   Min: 1.00\n   Max: 4.00\nAvailable Days Information: Total number with data: 2\n   Mean: 31.00\n   Std Dev: 0.00\n   Median: 31.00\n   Min: 31.00\n   Max: 31.00\nBlocked Days Information: Total number with data: 2\n   Mean: 0.00\n   Std Dev: 0.00\n   Median: 0.00\n   Min: 0.00\n   Max: 0.00\nResponse Rate Information: Total number with data: 2\n   Mean: 100.00\n   Std Dev: 0.00\n   Median: 100.00\n   Min: 100.00\n   Max: 100.00\nNumber of Reviews Information: Total number with data: 2\n   Mean: 9.00\n   Std Dev: 8.49\n   Median: 9.00\n   Min: 3.00\n   Max: 15.00\nMinimum Stay Information: Total number with data: 2\n   Mean: 9.00\n   Std Dev: 8.49\n   Median: 9.00\n   Min: 3.00\n   Max: 15.00\nNumber of Photos Information: Total number with data: 2\n   Mean: 14.00\n   Std Dev: 12.73\n   Median: 14.00\n   Min: 5.00\n   Max: 23.00\nOverall Rating Information: Total number with data: 2\n   Mean: 96.50\n   Std Dev: 4.95\n   Median: 96.50\n   Min: 93.00\n   Max: 100.00\n---------------------------------------------------------------------------\n\nAssume you are a data analyst that is familiar with AirBnB market. Give me the embedding of this 신길7동 at 2017-01-01',
#  '[2017-01-01 | 도봉2동] AirBnB Feature Summary:Total number of AirBnB: 2\nCategory Column Attributes\n\nCategory: Property Type Information: Total number with data: 2\n   Apartment: 2\n\nCategory: Listing Type Information: Total number with data: 2\n   Private room: 1\n   Entire home/apt: 1\n\nCategory: Airbnb Response Time (Text) Information: Total number with data: 2\n\nCategory: Cancellation Policy Information: Total number with data: 2\n   moderate: 1\n   flexible: 1\n\nCategory: Check-in Time Information: Total number with data: 2\n   Flexible: 2\n\nCategory: Checkout Time Information: Total number with data: 2\n   11AM: 1\n   12AM (midnight): 1\n\nCategory: Amenities Information: Total number with data: 24\n   heating: 2\n   wireless_internet: 2\n   ac: 2\n   essentials: 1\n   kitchen: 2\n   shampoo: 1\n   washer: 2\n   tv: 1\n   cable: 1\n   elevator: 1\n   dryer: 1\n   free_parking: 1\n   breakfast: 1\n   internet: 2\n---------------------------------------------------------------------------\n\nBinary Column Attributes\n\nAirbnb Superhost Information: Total number with data: 2\nnumber of Airbnb Superhost: 0\nInstantbook Enabled Information: Total number with data: 2\nnumber of Instantbook Enabled: 2\nPets Allowed Information: Total number with data: 2\nnumber of Pets Allowed: 1\n---------------------------------------------------------------------------\n\nNumerical Column Attributes\nBedrooms Information: Total number with data: 2\n   Mean: 1.00\n   Std Dev: 0.00\n   Median: 1.00\n   Min: 1.00\n   Max: 1.00\nBathrooms Information: Total number with data: 2\n   Mean: 1.00\n   Std Dev: 0.00\n   Median: 1.00\n   Min: 1.00\n   Max: 1.00\nMax Guests Information: Total number with data: 2\n   Mean: 3.50\n   Std Dev: 3.54\n   Median: 3.50\n   Min: 1.00\n   Max: 6.00\nAvailable Days Information: Total number with data: 2\n   Mean: 21.00\n   Std Dev: 8.49\n   Median: 21.00\n   Min: 15.00\n   Max: 27.00\nBlocked Days Information: Total number with data: 2\n   Mean: 0.50\n   Std Dev: 0.71\n   Median: 0.50\n   Min: 0.00\n   Max: 1.00\nResponse Rate Information: Total number with data: 1\n   Mean: 75.00\n   Std Dev: nan\n   Median: 75.00\n   Min: 75.00\n   Max: 75.00\nNumber of Reviews Information: Total number with data: 2\n   Mean: 12.50\n   Std Dev: 10.61\n   Median: 12.50\n   Min: 5.00\n   Max: 20.00\nMinimum Stay Information: Total number with data: 2\n   Mean: 1.00\n   Std Dev: 0.00\n   Median: 1.00\n   Min: 1.00\n   Max: 1.00\nNumber of Photos Information: Total number with data: 2\n   Mean: 19.00\n   Std Dev: 22.63\n   Median: 19.00\n   Min: 3.00\n   Max: 35.00\nOverall Rating Information: Total number with data: 1\n   Mean: 100.00\n   Std Dev: nan\n   Median: 100.00\n   Min: 100.00\n   Max: 100.00\n---------------------------------------------------------------------------\n\nAssume you are a data analyst that is familiar with AirBnB market. Give me the embedding of this 도봉2동 at 2017-01-01',
#  '[2017-01-01 | 신촌동] AirBnB Feature Summary:Total number of AirBnB: 275\nCategory Column Attributes\n\nCategory: Property Type Information: Total number with data: 275\n   Apartment: 65\n   Bed and breakfast: 55\n   House: 26\n   Rental unit: 26\n   Guesthouse: 16\n   Condominium: 11\n   Residential home: 8\n   Private room: 8\n   Bed & Breakfast: 8\n   Home: 7\n   Hostel: 7\n   Townhouse: 5\n   Private room in bed & breakfast: 3\n   Entire apartment: 3\n   Entire Floor: 3\n   Condo: 3\n   Serviced apartment: 2\n   Loft: 2\n   Room in hostel: 2\n   Villa: 2\n   Room in serviced apartment: 2\n   Other: 2\n   Private room in apartment: 1\n   Shared room in bed & breakfast: 1\n   Entire house: 1\n   Guest suite: 1\n   Tiny house: 1\n   Shared room in house: 1\n   Entire bed and breakfast: 1\n   Shared room in guesthouse: 1\n   Private room in hostel: 1\n\nCategory: Listing Type Information: Total number with data: 275\n   Private room: 149\n   Entire home/apt: 93\n   Shared room: 29\n   Hotel room: 4\n\nCategory: Airbnb Response Time (Text) Information: Total number with data: 275\n   within an hour: 101\n   within a few hours: 26\n   a few days or more: 11\n   within a day: 9\n\nCategory: Cancellation Policy Information: Total number with data: 275\n   strict_14_with_grace_period: 72\n   Strict: 50\n   moderate: 35\n   strict: 27\n   Strict - Free cancellation for 48 hours: 19\n   flexible: 16\n   Flexible: 11\n   Moderate - Free cancellation for 48 hours: 10\n   Moderate: 9\n   Strict · Free cancellation for 48 hours: 7\n   Flexible - Free cancellation for 48 hours: 6\n   Strict policy  –  Free cancellation within 48 hours: 4\n   firm: 3\n   Free cancellation for 48 hours: 2\n   Flexible · Free cancellation for 48 hours: 2\n   firm_30_strict: 1\n   Moderate · Free cancellation for 48 hours: 1\n\nCategory: Check-in Time Information: Total number with data: 275\n   After 3:00 PM: 62\n   After 3PM: 31\n   Anytime after 3PM: 30\n   1PM - 10PM: 15\n   Anytime after 2PM: 13\n   2PM - 10PM: 10\n   After 1PM: 7\n   Flexible: 7\n   3PM - 9PM: 6\n   After 2:00 PM: 6\n   3:00 PM - 11:00 PM: 6\n   After 4:00 PM: 6\n   3PM - 12AM (midnight): 5\n   3:00 PM - 10:00 PM: 4\n   2:00 PM - 10:00 PM: 4\n   3PM - 2AM (next day): 4\n   After 1:00 PM: 3\n   3:00 PM - 12:00 AM: 2\n   After 2PM: 2\n   After 10:00 AM: 2\n   10AM - 10PM: 2\n   12PM (noon) - 7PM: 2\n   2:00 PM - 11:00 PM: 2\n   Anytime after 4PM: 2\n   2PM - 11PM: 1\n   3:00 PM - 1:00 AM (next day): 1\n   After 10AM: 1\n   1:00 PM - 12:00 AM: 1\n   12:00 PM - 1:00 AM (next day): 1\n   2PM - 12AM (midnight): 1\n   3PM - 8PM: 1\n   2PM - 8PM: 1\n   After 11:00 AM: 1\n   1PM - 12AM (midnight): 1\n   4PM - 12AM (midnight): 1\n   4PM - 10PM: 1\n   After 7PM: 1\n   3PM - 11PM: 1\n   12PM (noon) - 10PM: 1\n   7PM - 12AM (midnight): 1\n   2:00 PM - 4:00 PM: 1\n   Anytime after 2AM: 1\n   Anytime after 12PM (noon): 1\n   10:00 AM - 2:00 PM: 1\n\nCategory: Checkout Time Information: Total number with data: 275\n   12PM (noon): 60\n   11AM: 60\n   11:00 AM: 56\n   12:00 PM: 40\n   10AM: 10\n   1PM: 5\n   10:00 AM: 5\n   2:00 PM: 4\n   5PM: 1\n   9:00 PM: 1\n   4PM: 1\n   2PM: 1\n\nCategory: Amenities Information: Total number with data: 4639\n   heating: 267\n   wireless_internet: 270\n   ac: 244\n   essentials: 193\n   kitchen: 242\n   shampoo: 166\n   washer: 259\n   hair-dryer: 176\n   hangers: 168\n   fire_extinguisher: 201\n   smoke_detector: 179\n   laptop-friendly: 165\n   tv: 195\n   hot_water: 79\n   iron: 131\n   carbon_monoxide_detector: 125\n   refrigerator: 54\n   dishes_and_silverware: 50\n   microwave: 46\n   long_term_stays_allowed: 63\n   first_aid_kit: 151\n   stove: 45\n   cable: 131\n   bed_linens: 56\n   cooking_basics: 41\n   elevator: 75\n   dryer: 94\n   keypad: 32\n   private-entrance: 41\n   luggage_dropoff_allowed: 53\n   free_parking: 55\n   lock_on_bedroom_door: 109\n   extra_pillows_and_blankets: 29\n   breakfast: 95\n   coffee_maker: 26\n   paid_parking: 27\n   room_dar ...
#  '[2017-01-01 | 행운동] AirBnB Feature Summary:Total number of AirBnB: 24\nCategory Column Attributes\n\nCategory: Property Type Information: Total number with data: 24\n   Loft: 9\n   Apartment: 6\n   Guest suite: 2\n   Bed & Breakfast: 2\n   Rental unit: 1\n   House: 1\n   Townhouse: 1\n   Home: 1\n   Bed and breakfast: 1\n\nCategory: Listing Type Information: Total number with data: 24\n   Private room: 16\n   Entire home/apt: 7\n   Shared room: 1\n\nCategory: Airbnb Response Time (Text) Information: Total number with data: 24\n   a few days or more: 3\n   within an hour: 2\n   within a day: 1\n\nCategory: Cancellation Policy Information: Total number with data: 24\n   flexible: 11\n   moderate: 8\n   Strict: 1\n   Strict - Free cancellation for 48 hours: 1\n   Flexible: 1\n   Moderate: 1\n   Moderate · Free cancellation for 48 hours: 1\n\nCategory: Check-in Time Information: Total number with data: 24\n   Flexible: 3\n   After 2PM: 2\n   Anytime after 2PM: 1\n   Anytime after 4PM: 1\n   3PM - 9PM: 1\n   After 3PM: 1\n   Anytime after 12AM (midnight): 1\n   2:00 PM - 6:00 PM: 1\n   After 2:00 PM: 1\n\nCategory: Checkout Time Information: Total number with data: 24\n   11:00 AM: 3\n   10AM: 2\n   12AM (midnight): 2\n   11AM: 2\n   12PM (noon): 1\n   10:00 AM: 1\n\nCategory: Amenities Information: Total number with data: 288\n   heating: 24\n   wireless_internet: 24\n   ac: 20\n   essentials: 8\n   kitchen: 22\n   shampoo: 8\n   washer: 23\n   hair-dryer: 5\n   hangers: 7\n   fire_extinguisher: 8\n   smoke_detector: 7\n   laptop-friendly: 7\n   tv: 18\n   hot_water: 3\n   iron: 4\n   carbon_monoxide_detector: 4\n   refrigerator: 2\n   dishes_and_silverware: 2\n   microwave: 2\n   long_term_stays_allowed: 2\n   first_aid_kit: 7\n   stove: 2\n   cable: 2\n   bed_linens: 2\n   cooking_basics: 2\n   elevator: 15\n   dryer: 7\n   keypad: 2\n   private-entrance: 2\n   luggage_dropoff_allowed: 2\n   free_parking: 12\n   lock_on_bedroom_door: 1\n   extra_pillows_and_blankets: 2\n   breakfast: 2\n   room_darkening_shades: 2\n   pocket_wifi: 2\n   ethernet_connection: 2\n   window_guards: 2\n   patio_or_balcony: 2\n   garden_or_backyard: 2\n   oven: 1\n   internet: 4\n---------------------------------------------------------------------------\n\nBinary Column Attributes\n\nAirbnb Superhost Information: Total number with data: 24\nnumber of Airbnb Superhost: 3\nInstantbook Enabled Information: Total number with data: 24\nnumber of Instantbook Enabled: 3\nPets Allowed Information: Total number with data: 24\nnumber of Pets Allowed: 0\n---------------------------------------------------------------------------\n\nNumerical Column Attributes\nBedrooms Information: Total number with data: 24\n   Mean: 1.00\n   Std Dev: 0.00\n   Median: 1.00\n   Min: 1.00\n   Max: 1.00\nBathrooms Information: Total number with data: 24\n   Mean: 1.00\n   Std Dev: 0.00\n   Median: 1.00\n   Min: 1.00\n   Max: 1.00\nMax Guests Information: Total number with data: 24\n   Mean: 2.38\n   Std Dev: 0.77\n   Median: 2.00\n   Min: 1.00\n   Max: 4.00\nAvailable Days Information: Total number with data: 24\n   Mean: 25.25\n   Std Dev: 8.29\n   Median: 29.00\n   Min: 4.00\n   Max: 31.00\nBlocked Days Information: Total number with data: 24\n   Mean: 3.00\n   Std Dev: 6.56\n   Median: 0.00\n   Min: 0.00\n   Max: 27.00\nResponse Rate Information: Total number with data: 24\n   Mean: 81.08\n   Std Dev: 20.58\n   Median: 80.00\n   Min: 0.00\n   Max: 100.00\nNumber of Reviews Information: Total number with data: 24\n   Mean: 9.67\n   Std Dev: 23.09\n   Median: 1.50\n   Min: 0.00\n   Max: 90.00\nMinimum Stay Information: Total number with data: 24\n   Mean: 3.42\n   Std Dev: 5.85\n   Median: 2.50\n   Min: 1.00\n   Max: 30.00\nNumber of Photos Information: Total number with data: 24\n   Mean: 15.33\n   Std Dev: 9.29\n   Median: 13.00\n   Min: 1.00\n   Max: 38.00\nOverall Rating Information: Total number with data: 18\n   Mean: 89.56\n   Std Dev: 8.67\n   Median: 89.00\n   Min: 80. ...
# ...
#  '[2017-03-01 | 다산동] AirBnB Feature Summary:Total number of AirBnB: 25\nCategory Column Attributes\n\nCategory: Property Type Information: Total number with data: 25\n   House: 5\n   Apartment: 4\n   Guesthouse: 4\n   Hostel: 3\n   Bed and breakfast: 2\n   Home: 2\n   Residential home: 1\n   Entire bed & breakfast: 1\n   Rental unit: 1\n   Townhouse: 1\n   Condo: 1\n\nCategory: Listing Type Information: Total number with data: 25\n   Private room: 18\n   Entire home/apt: 7\n\nCategory: Airbnb Response Time (Text) Information: Total number with data: 25\n   within an hour: 11\n   a few days or more: 3\n   within a day: 2\n   within a few hours: 2\n\nCategory: Cancellation Policy Information: Total number with data: 25\n   Flexible - Free cancellation for 48 hours: 6\n   strict_14_with_grace_period: 4\n   moderate: 4\n   Strict: 2\n   strict: 2\n   firm: 2\n   Moderate - Free cancellation for 48 hours: 1\n   Strict policy  –  Free cancellation within 48 hours: 1\n   flexible: 1\n   Moderate policy –  Free cancellation within 48 hours: 1\n   Strict · Free cancellation for 48 hours: 1\n\nCategory: Check-in Time Information: Total number with data: 25\n   After 3PM: 4\n   3PM - 11PM: 4\n   After 3:00 PM: 3\n   3:00 PM - 11:00 PM: 3\n   3:00 PM - 7:00 PM: 2\n   3PM - 10PM: 2\n   After 4:00 PM: 1\n   After 2:00 PM: 1\n   Anytime after 1PM: 1\n   Anytime after 2PM: 1\n   6PM - 11PM: 1\n   2PM - 1AM (next day): 1\n\nCategory: Checkout Time Information: Total number with data: 25\n   11AM: 8\n   11:00 AM: 6\n   12:00 PM: 4\n   10AM: 1\n   8AM: 1\n\nCategory: Amenities Information: Total number with data: 426\n   heating: 24\n   wireless_internet: 23\n   ac: 22\n   essentials: 22\n   kitchen: 20\n   shampoo: 21\n   washer: 20\n   hair-dryer: 19\n   hangers: 11\n   fire_extinguisher: 15\n   smoke_detector: 14\n   laptop-friendly: 9\n   tv: 17\n   hot_water: 8\n   iron: 13\n   carbon_monoxide_detector: 11\n   refrigerator: 6\n   dishes_and_silverware: 5\n   microwave: 5\n   long_term_stays_allowed: 3\n   first_aid_kit: 12\n   stove: 5\n   cable: 5\n   bed_linens: 5\n   cooking_basics: 6\n   elevator: 6\n   dryer: 12\n   keypad: 5\n   private-entrance: 3\n   luggage_dropoff_allowed: 4\n   free_parking: 7\n   lock_on_bedroom_door: 8\n   extra_pillows_and_blankets: 3\n   breakfast: 5\n   coffee_maker: 1\n   paid_parking: 3\n   room_darkening_shades: 1\n   paid_parking_on_premises: 1\n   host_checkin: 3\n   pocket_wifi: 1\n   ethernet_connection: 1\n   window_guards: 1\n   patio_or_balcony: 3\n   street_parking: 1\n---------------------------------------------------------------------------\n\nBinary Column Attributes\n\nAirbnb Superhost Information: Total number with data: 25\nnumber of Airbnb Superhost: 3\nInstantbook Enabled Information: Total number with data: 25\nnumber of Instantbook Enabled: 16\nPets Allowed Information: Total number with data: 25\nnumber of Pets Allowed: 0\n---------------------------------------------------------------------------\n\nNumerical Column Attributes\nBedrooms Information: Total number with data: 25\n   Mean: 1.16\n   Std Dev: 0.55\n   Median: 1.00\n   Min: 0.00\n   Max: 3.00\nBathrooms Information: Total number with data: 25\n   Mean: 1.22\n   Std Dev: 0.38\n   Median: 1.00\n   Min: 1.00\n   Max: 2.00\nMax Guests Information: Total number with data: 25\n   Mean: 2.16\n   Std Dev: 1.14\n   Median: 2.00\n   Min: 1.00\n   Max: 5.00\nAvailable Days Information: Total number with data: 25\n   Mean: 25.84\n   Std Dev: 8.41\n   Median: 30.00\n   Min: 6.00\n   Max: 31.00\nBlocked Days Information: Total number with data: 25\n   Mean: 1.04\n   Std Dev: 2.95\n   Median: 0.00\n   Min: 0.00\n   Max: 14.00\nResponse Rate Information: Total number with data: 25\n   Mean: 81.08\n   Std Dev: 37.49\n   Median: 100.00\n   Min: 0.00\n   Max: 100.00\nNumber of Reviews Information: Total number with data: 25\n   Mean: 25.16\n   Std Dev: 48.22\n   Median: 2.00\n   Min: 0.00\n   Max: 201.00\nMinimum Stay Information: Total number ...
#  '[2017-03-01 | 역삼2동] AirBnB Feature Summary:Total number of AirBnB: 63\nCategory Column Attributes\n\nCategory: Property Type Information: Total number with data: 63\n   Apartment: 33\n   House: 8\n   Bed and breakfast: 6\n   Guesthouse: 4\n   Rental unit: 4\n   Loft: 2\n   Serviced apartment: 1\n   Bed & Breakfast: 1\n   Dorm: 1\n   Place: 1\n   Entire apartment: 1\n   Hostel: 1\n\nCategory: Listing Type Information: Total number with data: 63\n   Entire home/apt: 43\n   Private room: 20\n\nCategory: Airbnb Response Time (Text) Information: Total number with data: 63\n   within an hour: 16\n   within a few hours: 1\n   a few days or more: 1\n\nCategory: Cancellation Policy Information: Total number with data: 63\n   moderate: 20\n   Strict: 12\n   Flexible - Free cancellation for 48 hours: 10\n   Moderate: 7\n   flexible: 4\n   strict_14_with_grace_period: 3\n   Strict - Free cancellation for 48 hours: 2\n   strict: 2\n   Moderate - Free cancellation for 48 hours: 1\n   Flexible: 1\n   Strict policy  –  Free cancellation within 48 hours: 1\n\nCategory: Check-in Time Information: Total number with data: 63\n   Anytime after 3PM: 26\n   After 3PM: 5\n   After 3:00 PM: 3\n   Anytime after 1PM: 2\n   3PM - 12AM (midnight): 2\n   3PM - 11PM: 2\n   Flexible: 2\n   Anytime after 2PM: 2\n   After 10AM: 1\n   3PM - 10PM: 1\n   3:00 PM - 2:00 AM (next day): 1\n   After 2PM: 1\n   3PM - 2AM (next day): 1\n   12:00 PM - 8:00 PM: 1\n   After 4PM: 1\n   3:00 PM - 11:00 PM: 1\n   1PM - 12AM (midnight): 1\n   2PM - 8PM: 1\n   3:00 PM - 12:00 AM: 1\n   3PM - 5PM: 1\n   10AM - 5PM: 1\n\nCategory: Checkout Time Information: Total number with data: 63\n   11AM: 30\n   12PM (noon): 11\n   11:00 AM: 3\n   12:00 PM: 2\n   3:00 PM: 1\n   1:00 PM: 1\n   10AM: 1\n   4PM: 1\n   5PM: 1\n\nCategory: Amenities Information: Total number with data: 915\n   heating: 61\n   wireless_internet: 58\n   ac: 58\n   essentials: 32\n   kitchen: 59\n   shampoo: 29\n   washer: 58\n   hair-dryer: 25\n   hangers: 29\n   fire_extinguisher: 23\n   smoke_detector: 26\n   laptop-friendly: 25\n   tv: 58\n   hot_water: 6\n   iron: 25\n   carbon_monoxide_detector: 23\n   refrigerator: 6\n   dishes_and_silverware: 6\n   microwave: 6\n   long_term_stays_allowed: 5\n   first_aid_kit: 18\n   stove: 5\n   cable: 40\n   bed_linens: 3\n   cooking_basics: 4\n   elevator: 38\n   dryer: 15\n   keypad: 7\n   private-entrance: 1\n   luggage_dropoff_allowed: 4\n   free_parking: 25\n   lock_on_bedroom_door: 11\n   extra_pillows_and_blankets: 3\n   breakfast: 1\n   coffee_maker: 3\n   paid_parking: 1\n   room_darkening_shades: 1\n   paid_parking_on_premises: 3\n   window_guards: 2\n   cleaning_before_checkout: 2\n   oven: 1\n   internet: 26\n   single_level_home: 1\n---------------------------------------------------------------------------\n\nBinary Column Attributes\n\nAirbnb Superhost Information: Total number with data: 63\nnumber of Airbnb Superhost: 1\nInstantbook Enabled Information: Total number with data: 63\nnumber of Instantbook Enabled: 38\nPets Allowed Information: Total number with data: 63\nnumber of Pets Allowed: 5\n---------------------------------------------------------------------------\n\nNumerical Column Attributes\nBedrooms Information: Total number with data: 63\n   Mean: 1.10\n   Std Dev: 0.69\n   Median: 1.00\n   Min: 0.00\n   Max: 4.00\nBathrooms Information: Total number with data: 63\n   Mean: 1.10\n   Std Dev: 0.37\n   Median: 1.00\n   Min: 0.50\n   Max: 3.00\nMax Guests Information: Total number with data: 63\n   Mean: 2.84\n   Std Dev: 2.24\n   Median: 2.00\n   Min: 1.00\n   Max: 12.00\nAvailable Days Information: Total number with data: 63\n   Mean: 20.97\n   Std Dev: 10.34\n   Median: 24.00\n   Min: 0.00\n   Max: 31.00\nBlocked Days Information: Total number with data: 63\n   Mean: 2.57\n   Std Dev: 6.10\n   Median: 0.00\n   Min: 0.00\n   Max: 27.00\nResponse Rate Information: Total number with data: 62\n   Mean: 88.16\n   Std Dev: 23.00\n   Median: 100.00\ ...
#  '[2017-03-01 | 강일동] AirBnB Feature Summary:Total number of AirBnB: 1\nCategory Column Attributes\n\nCategory: Property Type Information: Total number with data: 1\n   Apartment: 1\n\nCategory: Listing Type Information: Total number with data: 1\n   Entire home/apt: 1\n\nCategory: Airbnb Response Time (Text) Information: Total number with data: 1\n\nCategory: Cancellation Policy Information: Total number with data: 1\n   Flexible: 1\n\nCategory: Check-in Time Information: Total number with data: 1\n   3PM - 11PM: 1\n\nCategory: Checkout Time Information: Total number with data: 1\n   11AM: 1\n\nCategory: Amenities Information: Total number with data: 4\n   heating: 1\n   kitchen: 1\n   washer: 1\n   tv: 1\n---------------------------------------------------------------------------\n\nBinary Column Attributes\n\nAirbnb Superhost Information: Total number with data: 1\nnumber of Airbnb Superhost: 0\nInstantbook Enabled Information: Total number with data: 1\nnumber of Instantbook Enabled: 1\nPets Allowed Information: Total number with data: 1\nnumber of Pets Allowed: False\n---------------------------------------------------------------------------\n\nNumerical Column Attributes\nBedrooms Information: Total number with data: 1\n   Mean: 1.00\n   Std Dev: nan\n   Median: 1.00\n   Min: 1.00\n   Max: 1.00\nBathrooms Information: Total number with data: 1\n   Mean: 1.00\n   Std Dev: nan\n   Median: 1.00\n   Min: 1.00\n   Max: 1.00\nMax Guests Information: Total number with data: 1\n   Mean: 2.00\n   Std Dev: nan\n   Median: 2.00\n   Min: 2.00\n   Max: 2.00\nAvailable Days Information: Total number with data: 1\n   Mean: 21.00\n   Std Dev: nan\n   Median: 21.00\n   Min: 21.00\n   Max: 21.00\nBlocked Days Information: Total number with data: 1\n   Mean: 0.00\n   Std Dev: nan\n   Median: 0.00\n   Min: 0.00\n   Max: 0.00\nResponse Rate Information: Total number with data: 1\n   Mean: 80.00\n   Std Dev: nan\n   Median: 80.00\n   Min: 80.00\n   Max: 80.00\nNumber of Reviews Information: Total number with data: 1\n   Mean: 4.00\n   Std Dev: nan\n   Median: 4.00\n   Min: 4.00\n   Max: 4.00\nMinimum Stay Information: Total number with data: 1\n   Mean: 1.00\n   Std Dev: nan\n   Median: 1.00\n   Min: 1.00\n   Max: 1.00\nNumber of Photos Information: Total number with data: 1\n   Mean: 12.00\n   Std Dev: nan\n   Median: 12.00\n   Min: 12.00\n   Max: 12.00\nOverall Rating Information: Total number with data: 1\n   Mean: 85.00\n   Std Dev: nan\n   Median: 85.00\n   Min: 85.00\n   Max: 85.00\n---------------------------------------------------------------------------\n\nAssume you are a data analyst that is familiar with AirBnB market. Give me the embedding of this 강일동 at 2017-03-01',
#  '[2017-03-01 | 방배2동] AirBnB Feature Summary:Total number of AirBnB: 14\nCategory Column Attributes\n\nCategory: Property Type Information: Total number with data: 14\n   House: 6\n   Home: 4\n   Apartment: 4\n\nCategory: Listing Type Information: Total number with data: 14\n   Private room: 9\n   Entire home/apt: 3\n   Shared room: 2\n\nCategory: Airbnb Response Time (Text) Information: Total number with data: 14\n   a few days or more: 3\n   within an hour: 2\n   within a few hours: 2\n   within a day: 1\n\nCategory: Cancellation Policy Information: Total number with data: 14\n   flexible: 4\n   strict: 2\n   strict_14_with_grace_period: 2\n   moderate: 2\n   Moderate - Free cancellation for 48 hours: 2\n   Flexible policy –  Free cancellation within 48 hours: 1\n   Flexible: 1\n\nCategory: Check-in Time Information: Total number with data: 14\n   Anytime after 3PM: 3\n   3PM - 10PM: 2\n   3:00 PM - 10:00 PM: 2\n   After 5:00 PM: 1\n   After 3PM: 1\n   After 3:00 PM: 1\n\nCategory: Checkout Time Information: Total number with data: 14\n   11:00 AM: 3\n   11AM: 3\n\nCategory: Amenities Information: Total number with data: 157\n   heating: 12\n   wireless_internet: 12\n   ac: 10\n   essentials: 6\n   kitchen: 11\n   shampoo: 8\n   washer: 12\n   hair-dryer: 8\n   hangers: 6\n   fire_extinguisher: 7\n   smoke_detector: 2\n   laptop-friendly: 3\n   tv: 7\n   hot_water: 1\n   iron: 5\n   carbon_monoxide_detector: 1\n   refrigerator: 1\n   dishes_and_silverware: 1\n   microwave: 1\n   long_term_stays_allowed: 1\n   first_aid_kit: 1\n   cable: 2\n   cooking_basics: 1\n   elevator: 3\n   keypad: 2\n   free_parking: 6\n   lock_on_bedroom_door: 2\n   breakfast: 5\n   coffee_maker: 1\n   paid_parking: 1\n   room_darkening_shades: 1\n   paid_parking_on_premises: 1\n   ethernet_connection: 1\n   window_guards: 1\n   street_parking: 1\n   oven: 1\n   internet: 1\n---------------------------------------------------------------------------\n\nBinary Column Attributes\n\nAirbnb Superhost Information: Total number with data: 14\nnumber of Airbnb Superhost: 0\nInstantbook Enabled Information: Total number with data: 14\nnumber of Instantbook Enabled: 5\nPets Allowed Information: Total number with data: 14\nnumber of Pets Allowed: 1\n---------------------------------------------------------------------------\n\nNumerical Column Attributes\nBedrooms Information: Total number with data: 14\n   Mean: 1.00\n   Std Dev: 0.00\n   Median: 1.00\n   Min: 1.00\n   Max: 1.00\nBathrooms Information: Total number with data: 14\n   Mean: 1.11\n   Std Dev: 0.29\n   Median: 1.00\n   Min: 1.00\n   Max: 2.00\nMax Guests Information: Total number with data: 14\n   Mean: 2.43\n   Std Dev: 1.09\n   Median: 2.00\n   Min: 1.00\n   Max: 5.00\nAvailable Days Information: Total number with data: 14\n   Mean: 23.64\n   Std Dev: 8.43\n   Median: 29.00\n   Min: 10.00\n   Max: 31.00\nBlocked Days Information: Total number with data: 14\n   Mean: 1.29\n   Std Dev: 4.25\n   Median: 0.00\n   Min: 0.00\n   Max: 16.00\nResponse Rate Information: Total number with data: 14\n   Mean: 71.36\n   Std Dev: 41.82\n   Median: 100.00\n   Min: 0.00\n   Max: 100.00\nNumber of Reviews Information: Total number with data: 14\n   Mean: 12.79\n   Std Dev: 25.44\n   Median: 4.00\n   Min: 0.00\n   Max: 96.00\nMinimum Stay Information: Total number with data: 14\n   Mean: 2.07\n   Std Dev: 2.02\n   Median: 1.00\n   Min: 1.00\n   Max: 7.00\nNumber of Photos Information: Total number with data: 14\n   Mean: 9.57\n   Std Dev: 11.03\n   Median: 3.00\n   Min: 1.00\n   Max: 39.00\nOverall Rating Information: Total number with data: 8\n   Mean: 89.50\n   Std Dev: 7.41\n   Median: 86.50\n   Min: 80.00\n   Max: 100.00\n---------------------------------------------------------------------------\n\nAssume you are a data analyst that is familiar with AirBnB market. Give me the embedding of this 방배2동 at 2017-03-01',
#  ...]

# %%
airbnb_SSP_wo_listing = df_keys.copy()
airbnb_SSP_w_listing = df_keys.copy()

# %%
airbnb_SSP_wo_listing['prompt'] = SSP_prompt_wo_listing
airbnb_SSP_w_listing['prompt'] = SSP_prompt_w_listing

# %%
print(airbnb_SSP_wo_listing.shape)
print(airbnb_SSP_w_listing.shape)

airbnb_SSP_wo_listing.head()

# 여기까지 실행함...
# Out:
# (28408, 3)
# (28408, 3)
#   Reporting Month Dong_name                                             prompt
# 0      2017-01-01       혜화동  [2017-01-01 | 혜화동] AirBnB Feature Summary:Tota...
# 1      2017-01-01       사근동  [2017-01-01 | 사근동] AirBnB Feature Summary:Tota...
# 2      2017-01-01       연남동  [2017-01-01 | 연남동] AirBnB Feature Summary:Tota...
# 3      2017-01-01       우이동  [2017-01-01 | 우이동] AirBnB Feature Summary:Tota...
# 4      2017-01-01       사직동  [2017-01-01 | 사직동] AirBnB Feature Summary:Tota...

# %%
airbnb_SSP_w_listing.head()
# Out:
#   Reporting Month Dong_name                                             prompt
# 0      2017-01-01       혜화동  [2017-01-01 | 혜화동] AirBnB Feature Summary:Tota...
# 1      2017-01-01       사근동  [2017-01-01 | 사근동] AirBnB Feature Summary:Tota...
# 2      2017-01-01       연남동  [2017-01-01 | 연남동] AirBnB Feature Summary:Tota...
# 3      2017-01-01       우이동  [2017-01-01 | 우이동] AirBnB Feature Summary:Tota...
# 4      2017-01-01       사직동  [2017-01-01 | 사직동] AirBnB Feature Summary:Tota...

# %%
airbnb_SSP_wo_listing.to_csv('../dong_prompts_new/AirBnB_SSP_wo_prompts.csv', index=False)
airbnb_SSP_w_listing.to_csv('../dong_prompts_new/AirBnB_SSP_w_prompts.csv', index=False)
